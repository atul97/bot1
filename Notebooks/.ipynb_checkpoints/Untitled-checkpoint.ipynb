# %% [markdown]
# # Automate Files

# %% [markdown]
# ## nlu.yml

# %%
import pandas as pd

def extract_intent_examples(df):
    last_intent=""
    dic={}
    for ind in df.index:
         if(df.intent[ind].strip()==last_intent):
            dic[last_intent].append(df.examples[ind].strip())
         else:
            last_intent=df.intent[ind].strip()
            dic[last_intent]=[df.examples[ind].strip()]
    print(dic)
    return dic

# %%
def write_nlu(source_dict,target_file_src):
    target_file = open(target_file_src,"w")
    output = ["version: \"2.0\" \n \nnlu: \n"]
    s=""
    for i in source_dict:
        s+="- intent: "+i+"\n"+"  examples: |\n"
        li_int_exmpl = source_dict[i]
        for j in li_int_exmpl:
            s+="    - "+j+"\n"
        s+="\n"
    output.append(s)
    target_file.writelines(output)
    target_file.close()

# %%
df = pd.read_csv('nlu.csv')
dic_intent_example=extract_intent_examples(df)
nlu_file= "nlu.yml"
write_nlu(dic_intent_example,nlu_file)

# %% [markdown]
# ## Read nlu.yml file and change to excel

# %%
nlu_file= "nlu.yml"
src_nlu_file = open(nlu_file,"r")
intent = ""
intent_flg = 0
list_intent = []
list_example = []
output_csv = open('csvfile.csv','w')
output_csv.write('intent,example\n')
with open(nlu_file,"r") as file:
    for line in file:
        if "intent" in line:
            intent = line.split(":")[-1].strip()
            intent_flg = 1
        elif intent_flg == 1 and "-" in line:
            intent_example = line.split(" ")[-1].rstrip("\n")
            
            output_csv.write(f'{intent},{intent_example}\n')
            
output_csv.close()

# %%
list_intent
# Out:
# [{'greet': 'hey'},
#  {'greet': 'hello'},
#  {'greet': 'hi'},
#  {'greet': 'there'},
#  {'greet': 'morning'},
#  {'greet': 'evening'},
#  {'greet': 'moin'},
#  {'greet': 'there'},
#  {'greet': 'go'},
#  {'greet': 'dude'},
#  {'greet': 'goodmorning'},
#  {'greet': 'goodevening'},
#  {'greet': 'afternoon'},
#  {'Home': 'Menu'},
#  {'Home': 'main_menu'},
#  {'Home': 'Menu'},
#  {'Home': 'Main'},
#  {'Home': 'menu'},
#  {'Home': 'restart'},
#  {'Home': 'Restart'},
#  {'Home': 'Home'},
#  {'Home': 'Home'},
#  {'goodbye': 'afternoon'},
#  {'goodbye': 'cu'},
#  {'goodbye': 'by'},
#  {'goodbye': 'later'},
#  {'goodbye': 'night'},
#  {'goodbye': 'bye'},
#  {'goodbye': 'goodbye'},
#  {'goodbye': 'day'},
#  {'goodbye': 'around'},
#  {'goodbye': 'bye'},
#  {'goodbye': 'later'},
#  {'affirm': 'yes'},
#  {'affirm': 'y'},
#  {'affirm': 'indeed'},
#  {'affirm': 'course'},
#  {'affirm': 'good'},
#  {'affirm': 'correct'},
#  {'deny': 'no'},
#  {'deny': 'n'},
#  {'deny': 'never'},
#  {'deny': 'so'},
#  {'deny': 'that'},
#  {'deny': 'way'},
#  {'deny': 'really'},
#  {'quit': 'quit'},
#  {'quit': 'Quit'},
#  {'quit': 'stop'},
#  {'Account_Management': 'Account_Management'},
#  {'Account_Management': 'Management'},
#  {'Account_Management': 'Lock'},
#  {'Account_Management': 'Unlock'},
#  {'Account_Management': 'Password'},
#  {'Account_Management': 'reset'},
#  {'Account_Management': 'Password'},
#  {'Account_Management': 'login'},
#  {'Account_Management': 'login'},
#  {'Reset_Password': 'Reset_Password'},
#  {'Reset_Password': 'Password'},
#  {'Reset_Password': 'Reset'},
#  {'Reset_Password': 'Password'},
#  {'Account_Unlock': 'Account_Unlock'},
#  {'Account_Unlock': 'Unlock'},
#  {'Account_Unlock': 'AccountUnlock'},
#  {'Account_Unlock': 'Locked'},
#  {'Ticket_Management': 'Ticket_Management'},
#  {'Ticket_Management': 'Management'},
#  {'Ticket_Management': 'ticket'},
#  {'Ticket_Management': 'log'},
#  {'Ticket_Management': 'ticket'},
#  {'Ticket_Management': 'ticket'},
#  {'Ticket_Management': 'ticket'},
#  {'raise_ticket': 'raise_ticket'},
#  {'raise_ticket': 'Ticket'},
#  {'ticket_status': 'status'},
#  {'ticket_status': 'status'},
#  {'ticket_status': 'ticket_status'},
#  {'Software_Deployment': 'Software_Deployment'},
#  {'Software_Deployment': 'Deployment'},
#  {'Software_Deployment': 'SoftwareDeployment'},
#  {'Software_Deployment': 'Skype'},
#  {'Software_Deployment': 'Software'},
#  {'Software_Deployment': 'Chrome'},
#  {'Software_Deployment': 'driver'},
#  {'Software_Deployment': 'installation'},
#  {'Software_Deployment': 'install'},
#  {'Troubleshoot': 'Troubleshoot'},
#  {'Troubleshoot': 'Wifi'},
#  {'Troubleshoot': 'Wi-Fi'},
#  {'Troubleshoot': 'Browser'},
#  {'Troubleshoot': 'Browser'},
#  {'Troubleshoot': 'internet'},
#  {'Troubleshoot': 'connectivity'},
#  {'Troubleshoot': 'connection'},
#  {'Troubleshoot': 'Cache'},
#  {'Troubleshoot': 'cookies'},
#  {'Troubleshoot': 'junk'},
#  {'Troubleshoot': 'space'},
#  {'Troubleshoot': 'disk'},
#  {'Troubleshoot': 'clean'},
#  {'Troubleshoot': 'Troubleshoot'},
#  {'Troubleshoot': 'SoftwareTroubleshoot'},
#  {'Troubleshoot': 'Troubleshoot'},
#  {'WiFi_Troubleshoot': 'Troubleshoot'},
#  {'WiFi_Troubleshoot': 'WiFi_Troubleshoot'},
#  {'WiFi_Troubleshoot': 'Troubleshoot'},
#  {'Camera_Troubleshoot': 'Troubleshoot'},
#  {'Camera_Troubleshoot': 'Camera_Troubleshoot'},
#  {'Camera_Troubleshoot': 'Camera'},
#  {'Microphone_Troubleshoot': 'Troubleshoot'},
#  {'Microphone_Troubleshoot': 'Microphone_Troubleshoot'},
#  {'Microphone_Troubleshoot': 'Microphone'},
#  {'Clear_Browser_Cache': 'Clear_Browser_Cache'},
#  {'Clear_Browser_Cache': 'Cache'},
#  {'Clear_Browser_Cache': 'ClearBrowserCache'},
#  {'Clear_Browser_Cache': 'Cache'},
#  {'Clear_Browser_Cache': 'Cookies'},
#  {'Clear_Browser_Cache': 'issue'},
#  {'Clear_Browser_Cache': 'Browser'},
#  {'Clear_Browser_Cache': 'internet'},
#  {'Clear_Browser_Cache': 'bot?'},
#  {'Clear_Chrome_Cache': 'human?'},
#  {'Clear_Chrome_Cache': 'bot?'},
#  {'Clear_Chrome_Cache': 'human?'},
#  {'Clear_Edge_Cache': 'Clear_Edge_Cache'},
#  {'Clear_Edge_Cache': 'Cache'},
#  {'Clear_Edge_Cache': 'ClearEdgeCache'},
#  {'Clear_Mozilla_Cache': 'Clear_Mozilla_Cache'},
#  {'Clear_Mozilla_Cache': 'Cache'},
#  {'Clear_Mozilla_Cache': 'ClearMozillaCache'},
#  {'Remove_Space': 'Space'},
#  {'Remove_Space': 'RemoveSpace'},
#  {'Remove_Space': 'Remove_Space'},
#  {'Printer_Management': 'Management'},
#  {'Printer_Management': 'Printer_Management'},
#  {'Printer_Management': 'PrinterManagement'},
#  {'Printer_Management': 'Issue'},
#  {'Collect_Feedback': 'Collect_Feedback'},
#  {'Collect_Feedback': 'Feedback'},
#  {'Collect_Feedback': 'CollectFeedback'},
#  {'Collect_Feedback': 'Feedback'},
#  {'Not_Satisfied': 'Satisfied'},
#  {'Not_Satisfied': 'Not_Satisfied'},
#  {'mood_great': 'perfect'},
#  {'mood_great': 'great'},
#  {'mood_great': 'amazing'},
#  {'mood_great': 'king'},
#  {'mood_great': 'wonderful'},
#  {'mood_great': 'good'},
#  {'mood_great': 'great'},
#  {'mood_great': 'amazing'},
#  {'mood_great': 'world'},
#  {'mood_great': 'stoked'},
#  {'mood_great': 'good'},
#  {'mood_great': 'perfect'},
#  {'mood_great': 'good'},
#  {'mood_great': 'perfect'},
#  {'mood_unhappy': 'horrible'},
#  {'mood_unhappy': 'sad'},
#  {'mood_unhappy': 'well'},
#  {'mood_unhappy': 'disappointed'},
#  {'mood_unhappy': 'sad'},
#  {'mood_unhappy': 'sad'},
#  {'mood_unhappy': 'sad'},
#  {'mood_unhappy': 'sad'},
#  {'mood_unhappy': 'unhappy'},
#  {'mood_unhappy': 'good'},
#  {'mood_unhappy': 'good'},
#  {'mood_unhappy': 'sad'},
#  {'mood_unhappy': 'saad'},
#  {'mood_unhappy': 'sad'},
#  {'bot_challenge': 'bot?'},
#  {'bot_challenge': 'human?'},
#  {'bot_challenge': 'bot?'},
#  {'bot_challenge': 'human?'}]

# %%
df2 = pd.DataFrame(list(zip(list_intent,list_example)),columns=['intent','example'],index=None)

# %%
df2.to_excel("nlu2.xlsx")
